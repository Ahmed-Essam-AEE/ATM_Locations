# %%
import pandas as pd
import openpyxl
import numpy as np

# %%
workbook = pd.read_excel('nearest_atm3.xlsx')
workbook
# Out:
#         ID governerate            region  \
# 0        1   Al Fayyum  Markaz Al-Fayyum
# 1        2   Al Fayyum  Markaz Al-Fayyum
# 2        3   Al Fayyum  Markaz Al-Fayyum
# 3        4   Al Fayyum   Markaz Sinnuris
# 4        5   Al Fayyum       Markaz Itsa
# ...    ...         ...               ...
# 4258  4259   As Suways    Kism Al-Arb'in
# 4259  4260   As Suways      Kism 'Ataqah
# 4260  4261   As Suways      Kism 'Ataqah
# 4261  4262   As Suways    Kism Al-Arb'in
# 4262  4263   As Suways    Kism Al-Arb'in
#
#                                                 Address        Lat       Long  \
# 0                         Alfayoum Beghous Alhoriea St.  29.304412  30.853546
# 1                                     Fayoum University  29.319696  30.835641
# 2                                   Fayoum AlHoriea St.  29.308199  30.842229
# 3                                      Sanoras - Fayoum  29.408575  30.865073
# ...

# %%
workbook.groupby('region').describe()

# %%
new = workbook.groupby(['region']).size()
display(new)
# Out:
# region
# City Dishna                               11
# City New Burj al-'Arab City               12
# City New Minya City                        3
# Kism 'Abdin                               30
# Kism 'Ain Schams                          25
#                                           ..
# unorganized Unorganized in Aswan          13
# unorganized Unorganized in Asyut           5
# unorganized Unorganized in Bani Suwayf     2
# unorganized Unorganized in Qina            4
# unorganized Unorganized in Suhaj           2
# Length: 303, dtype: int64

# %%
new.to_excel('num_of_atms_at_regions.xlsx', sheet_name='atms_region')

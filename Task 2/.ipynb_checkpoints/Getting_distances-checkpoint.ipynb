# %%
# import geopandas as gpd
# import geopy
# from shapely.geometry import Point
# from geopy.geocoders import Nominatim

import pandas as pd
import numpy as np

import mpu
import seaborn as sns

#pd.set_option('display.max_rows', 10000)
#pd.set_option('display.max_columns', 10000)
#pd.set_option('display.width', 10000)

# %%
df = pd.read_excel('atm_bank_misr.xlsx')
#df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4263 entries, 0 to 4262
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4263 non-null   int64
#  1   governerate  4263 non-null   object
#  2   region       4263 non-null   object
#  3   Address      4263 non-null   object
#  4   Lat          4263 non-null   float64
#  5   Long         4263 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 200.0+ KB

# %%
df.head()
# Out:
#    ID governerate            region  \
# 0   1   Al Fayyum  Markaz Al-Fayyum
# 1   2   Al Fayyum  Markaz Al-Fayyum
# 2   3   Al Fayyum  Markaz Al-Fayyum
# 3   4   Al Fayyum   Markaz Sinnuris
# 4   5   Al Fayyum       Markaz Itsa
#
#                                          Address        Lat       Long
# 0                  Alfayoum Beghous Alhoriea St.  29.304412  30.853546
# 1                              Fayoum University  29.319696  30.835641
# 2                            Fayoum AlHoriea St.  29.308199  30.842229
# 3                               Sanoras - Fayoum  29.408575  30.865073
# 4  194 Abo Bakr AlSiddiq St.- Atsa City - Fayoum  29.236966  30.790194

# %%
df.iloc[[55,132]]
# Out:
#       ID  governerate             region                     Address  \
# 55    56  Al Buhayrah  Markaz Abu Hummus  The local unit - Abo Homos
# 132  133  Al Buhayrah  Markaz Abu Hummus  The local unit - Abo Homos
#
#            Lat      Long
# 55   31.100602  30.31555
# 132  31.100602  30.31555

# %%
lat_longs = np.array(df[['Lat','Long']])#

# %%
df
# Out:
#         ID governerate            region  \
# 0        1   Al Fayyum  Markaz Al-Fayyum
# 1        2   Al Fayyum  Markaz Al-Fayyum
# 2        3   Al Fayyum  Markaz Al-Fayyum
# 3        4   Al Fayyum   Markaz Sinnuris
# 4        5   Al Fayyum       Markaz Itsa
# ...    ...         ...               ...
# 4258  4259   As Suways    Kism Al-Arb'in
# 4259  4260   As Suways      Kism 'Ataqah
# 4260  4261   As Suways      Kism 'Ataqah
# 4261  4262   As Suways    Kism Al-Arb'in
# 4262  4263   As Suways    Kism Al-Arb'in
#
#                                                 Address        Lat       Long
# 0                         Alfayoum Beghous Alhoriea St.  29.304412  30.853546
# 1                                     Fayoum University  29.319696  30.835641
# 2                                   Fayoum AlHoriea St.  29.308199  30.842229
# 3                                      Sanoras - Fayoum  29.408575  30.865073
# 4         194 Abo Bakr AlSiddiq St.- Atsa City - Fayoum  29.236966  30.790194
# ...                                                 ...        ...        ...
# 4258                 Suez Canal Authority Water Company  29.967446  32.550833
# 4259                        K 36 Suez - Ain Sokhna Road  29.728850  32.381612
# 4260                    Suez Sokhna Road Canary Village  29.617352  32.317460
# 4261  AlGeish St. Suez District Suez in front of Oma...  29.967901  32.553257
# 4262  Two commercial stores numbers (12) located on ...  29.975812  32.546986
#
# [4263 rows x 6 columns]

# %%
k = 4


near_dis1 = [] # distance of nearest atm
index1 = [] # index of nearest atm

near_dis2 = []
index2 = []

near_dis3 = []
index3 = []

for i in range(len(lat_longs)):
    err_list = []
    
    for j in range(len(lat_longs)): 
        
        lat1,lon1,lat2,lon2 = lat_longs[i][0],lat_longs[i][1],lat_longs[j][0],lat_longs[j][1]
        err_list.append(mpu.haversine_distance((lat1, lon1), (lat2, lon2)))
    
    distances = np.array(err_list)
    least_k = np.argsort(distances)[1:k]
    print('Indexes of nearest lat_long',least_k)
    print('For lat_long',lat_longs[i],'the nearest lat_longs are:')
    print(lat_longs[least_k])
    print('With distances of:') 
    print(distances[least_k])
    
    least_k_distances = distances[least_k]
    near_dis1.append(least_k_distances[0])
    index1.append(least_k[0])
    near_dis2.append(least_k_distances[1])
    index2.append(least_k[1])
    near_dis3.append(least_k_distances[2])
    index3.append(least_k[2])
    print('-------------------------------------')
# Out:
# Indexes of nearest lat_long [21 29  9]
# For lat_long [29.30441208 30.85354563] the nearest lat_longs are:
# [[29.3029927  30.85296321]
#  [29.308889   30.847499  ]
#  [29.308889   30.847499  ]]
# With distances of:
# [0.1676278  0.76913315 0.76913315]
# -------------------------------------
# Indexes of nearest lat_long [32  7 31]
# For lat_long [29.319696 30.835641] the nearest lat_longs are:
# [[29.319696 30.835641]
#  [29.321487 30.837896]
#  [29.322145 30.837087]]
# With distances of:
# [0.         0.29573057 0.30628301]
# -------------------------------------
# Indexes of nearest lat_long [ 2  5 35]
# For lat_long [29.308199 30.842229] the nearest lat_longs are:
# [[29.308199   30.842229  ]
#  [29.30772267 30.84613982]
#  [29.304818   30.84385   ]]
# With distances of:
# [0.         0.38288298 0.40748412]
# -------------------------------------
# Indexes of nearest lat_long [16 25 20]
# For lat_long [29.40857519 30.86507307] the nearest lat_longs are:
# [[29.4087034  30.8587204 ]
#  [29.41540081 30.86429428]
#  [29.39694049 30.82468411]]
# With distances of:
# [0.61552473 0.7627144  4.12089861]
# -------------------------------------
# Indexes of nearest lat_long [28 27 35]
# For lat_long [29.23696578 30.79019445] the nearest lat_longs are:
# [[29.237697   30.795299  ]
#  [29.24143653 30.79518521]
#  [29.304818   30.84385   ]]
# With distances of:
# [0.50191914 0.69398916 9.16572808]
# -------------------------------------
# Indexes of nearest lat_long [29  9 17]
# For lat_long [29.30772267 30.84613982] the nearest lat_longs are:
# [[29.308889   30.847499  ]
#  [29.308889   30.847499  ]
#  [29.30973607 30.84764079]]
# With distances of:
# [0.18489921 0.18489921 0.2670263 ]
# -------------------------------------
# Indexes of nearest lat_long [14 33 34]
# For lat_long [29.31542035 30.85217852] the nearest lat_longs are:
# [[29.31563484 30.85253097]
#  [29.319011   30.851452  ]
#  [29.319011   30.851452  ]]
# With distances of:
# [0.04167194 0.40542763 0.40542763]
# -------------------------------------
# Indexes of nearest lat_long [31  8  1]
# For lat_long [29.321487 30.837896] the nearest lat_longs are:
# [[29.322145 30.837087]
#  [29.322145 30.837087]
#  [29.319696 30.835641]]
# With distances of:
# [0.10726059 0.10726059 0.29573057]
# -------------------------------------
# Indexes of nearest lat_long [8 7 1]
# For lat_long [29.322145 30.837087] the nearest lat_longs are:
# [[29.322145 30.837087]
#  [29.321487 30.837896]
#  [29.319696 30.835641]]
# With distances of:
# [0.         0.10726059 0.30628301]
# -------------------------------------
# Indexes of nearest lat_long [ 9 17  5]
# For lat_long [29.308889 30.847499] the nearest lat_longs are:
# [[29.308889   30.847499  ]
#  [29.30973607 30.84764079]
#  [29.30772267 30.84613982]]
# With distances of:
# [0.         0.09518794 0.18489921]
# -------------------------------------
# Indexes of nearest lat_long [35  5  2]
# For lat_long [29.304818 30.84385 ] the nearest lat_longs are:
# [[29.304818   30.84385   ]
#  [29.30772267 30.84613982]
#  [29.308199   30.842229  ]]
# With distances of:
# [0.         0.39193877 0.40748412]
# -------------------------------------
# Indexes of nearest lat_long [11 13 19]
# For lat_long [29.370735 30.688374] the nearest lat_longs are:
# [[29.370735   30.688374  ]
#  [29.36074053 30.68325785]
#  [29.38125621 30.77755288]]
# With distances of:
# [0.         1.21691135 8.72003811]
# -------------------------------------
# Indexes of nearest lat_long [34 12 14]
# For lat_long [29.319011 30.851452] the nearest lat_longs are:
# [[29.319011   30.851452  ]
#  [29.319011   30.851452  ]
#  [29.31563484 30.85253097]]
# With distances of:
# [0.        0.        0.3897143]
# -------------------------------------
# Indexes of nearest lat_long [36 11 19]
# For lat_long [29.36074053 30.68325785] the nearest lat_longs are:
# [[29.370735   30.688374  ]
#  [29.370735   30.688374  ]
#  [29.38125621 30.77755288]]
# With distances of:
# [1.21691135 1.21691135 9.41785586]
# -------------------------------------
# Indexes of nearest lat_long [ 6 33 34]
# For lat_long [29.31563484 30.85253097] the nearest lat_longs are:
# [[29.31542035 30.85217852]
#  [29.319011   30.851452  ]
#  [29.319011   30.851452  ]]
# With distances of:
# [0.04167194 0.3897143  0.3897143 ]
# -------------------------------------
# Indexes of nearest lat_long [25  3 16]
# For lat_long [29.47427641 30.9549612 ] the nearest lat_longs are:
# [[29.41540081 30.86429428]
#  [29.40857519 30.86507307]
#  [29.4087034  30.8587204 ]]
# With distances of:
# [10.95159548 11.36387414 11.83287622]
# -------------------------------------
# Indexes of nearest lat_long [ 3 25 20]
# For lat_long [29.4087034 30.8587204] the nearest lat_longs are:
# [[29.40857519 30.86507307]
#  [29.41540081 30.86429428]
#  [29.39694049 30.82468411]]
# With distances of:
# [0.61552473 0.91983711 3.54711969]
# -------------------------------------
# Indexes of nearest lat_long [29  9  5]
# For lat_long [29.30973607 30.84764079] the nearest lat_longs are:
# [[29.308889   30.847499  ]
#  [29.308889   30.847499  ]
#  [29.30772267 30.84613982]]
# With distances of:
# [0.09518794 0.09518794 0.2670263 ]
# -------------------------------------
# Indexes of nearest lat_long [20 16 25]
# For lat_long [29.41719986 30.81736238] the nearest lat_longs are:
# [[29.39694049 30.82468411]
#  [29.4087034  30.8587204 ]
#  [29.41540081 30.86429428]]
# With distances of:
# [2.36174832 4.11592625 4.55017747]
# -------------------------------------
# Indexes of nearest lat_long [24 20 18]
# For lat_long [29.38125621 30.77755288] the nearest lat_longs are:
# [[29.40740388 30.77005311]
#  [29.39694049 30.82468411]
#  [29.41719986 30.81736238]]
# With distances of:
# [2.99689883 4.8880193  5.55401232]
# -------------------------------------
# Indexes of nearest lat_long [18 16  3]
# For lat_long [29.39694049 30.82468411] the nearest lat_longs are:
# [[29.41719986 30.81736238]
#  [29.4087034  30.8587204 ]
#  [29.40857519 30.86507307]]
# With distances of:
# [2.36174832 3.54711969 4.12089861]
# -------------------------------------
# Indexes of nearest lat_long [ 0 29  9]
# For lat_long [29.3029927  30.85296321] the nearest lat_longs are:
# [[29.30441208 30.85354563]
#  [29.308889   30.847499  ]
#  [29.308889   30.847499  ]]
# With distances of:
# [0.1676278  0.84296134 0.84296134]
# -------------------------------------
# Indexes of nearest lat_long [ 4 27 28]
# For lat_long [29.24124675 30.67229435] the nearest lat_longs are:
# [[29.23696578 30.79019445]
#  [29.24143653 30.79518521]
#  [29.237697   30.795299  ]]
# With distances of:
# [11.44944672 11.92354547 11.94131066]
# -------------------------------------
# Indexes of nearest lat_long [1295 1340   21]
# For lat_long [29.20959358 30.9713821 ] the nearest lat_longs are:
# [[29.09317909 30.95394899]
#  [29.2100632  31.1103788 ]
#  [29.3029927  30.85296321]]
# With distances of:
# [13.05493451 13.49045272 15.48650389]
# -------------------------------------
# Indexes of nearest lat_long [19 18 20]
# For lat_long [29.40740388 30.77005311] the nearest lat_longs are:
# [[29.38125621 30.77755288]
#  [29.41719986 30.81736238]
#  [29.39694049 30.82468411]]
# With distances of:
# [2.99689883 4.71019018 5.41862419]
# -------------------------------------
# Indexes of nearest lat_long [ 3 16 20]
# For lat_long [29.41540081 30.86429428] the nearest lat_longs are:
# [[29.40857519 30.86507307]
#  [29.4087034  30.8587204 ]
#  [29.39694049 30.82468411]]
# With distances of:
# [0.7627144  0.91983711 4.35155189]
# -------------------------------------
# Indexes of nearest lat_long [ 3 34 33]
# For lat_long [29.3524194  30.96981294] the nearest lat_longs are:
# [[29.40857519 30.86507307]
#  [29.319011   30.851452  ]
#  [29.319011   30.851452  ]]
# With distances of:
# [11.91570592 12.05981257 12.05981257]
# -------------------------------------
# Indexes of nearest lat_long [28  4 35]
# For lat_long [29.24143653 30.79518521] the nearest lat_longs are:
# [[29.237697   30.795299  ]
#  [29.23696578 30.79019445]
#  [29.304818   30.84385   ]]
# With distances of:
# [0.41596331 0.69398916 8.48238213]
# -------------------------------------
# Indexes of nearest lat_long [27  4 35]
# For lat_long [29.237697 30.795299] the nearest lat_longs are:
# [[29.24143653 30.79518521]
#  [29.23696578 30.79019445]
#  [29.304818   30.84385   ]]
# With distances of:
# [0.41596331 0.50191914 8.82505236]
# -------------------------------------
# Indexes of nearest lat_long [ 9 17  5]
# For lat_long [29.308889 30.847499] the nearest lat_longs are:
# [[29.308889   30.847499  ]
#  [29.30973607 30.84764079]
#  [29.30772267 30.84613982]]
# With distances of:
# [0.         0.09518794 0.18489921]
# -------------------------------------
# Indexes of nearest lat_long [ 2  5 35]
# For lat_long [29.308199 30.842229] the nearest lat_longs are:
# [[29.308199   30.842229  ]
#  [29.30772267 30.84613982]
#  [29.304818   30.84385   ]]
# With distances of:
# [0.         0.38288298 0.40748412]
# -------------------------------------
# Indexes of nearest lat_long [8 7 1]
# For lat_long [29.322145 30.837087] the nearest lat_longs are:
# [[29.322145 30.837087]
#  [29.321487 30.837896]
#  [29.319696 30.835641]]
# With distances of:
# [0.         0.10726059 0.30628301]
# -------------------------------------
# Indexes of nearest lat_long [32  7 31]
# For lat_long [29.319696 30.835641] the nearest lat_longs are:
# [[29.319696 30.835641]
#  [29.321487 30.837896]
#  [29.322145 30.837087]]
# With distances of:
# [0.         0.29573057 0.30628301]
# -------------------------------------
# Indexes of nearest lat_long [34 12 14]
# For lat_long [29.319011 30.851452] the nearest lat_longs are:
# [[29.319011   30.851452  ]
#  [29.319011   30.851452  ]
#  [29.31563484 30.85253097]]
# With distances of:
# [0.        0.        0.3897143]
# -------------------------------------
# Indexes of nearest lat_long [34 12 14]
# For lat_long [29.319011 30.851452] the nearest lat_longs are:
# [[29.319011   30.851452  ]
#  [29.319011   30.851452  ]
#  [29.31563484 30.85253097]]
# With distances of:
# [0.        0.        0.3897143]
# -------------------------------------
# Indexes of nearest lat_long [35  5  2]
# For lat_long [29.304818 30.84385 ] the nearest lat_longs are:
# [[29.304818   30.84385   ]
#  [29.30772267 30.84613982]
#  [29.308199   30.842229  ]]
# With distances of:
# [0.         0.39193877 0.40748412]
# -------------------------------------
# Indexes of nearest lat_long [11 13 19]
# For lat_long [29.370735 30.688374] the nearest lat_longs are:
# [[29.370735   30.688374  ]
#  [29.36074053 30.68325785]
#  [29.38125621 30.77755288]]
# With distances of:
# [0.         1.21691135 8.72003811]
# -------------------------------------
# Indexes of nearest lat_long [1289 1288 1310]
# For lat_long [29.07578529 31.09938927] the nearest lat_longs are:
# [[29.07578529 31.09938927]
#  [29.07523208 31.09924149]
#  [29.07535899 31.09829712]]
# With distances of:
# [5.31824916e-07 6.31679329e-02 1.16241722e-01]
# -------------------------------------
# Indexes of nearest lat_long [ 190   43 3350]
# For lat_long [31.10691837 30.64172916] the nearest lat_longs are:
# [[31.10958367 30.63910172]
#  [31.103395   30.638362  ]
#  [31.12534257 30.64901408]]
# With distances of:
# [0.38782124 0.50622396 2.16287267]
# -------------------------------------
# Indexes of nearest lat_long [ 46 153  84]
# For lat_long [30.9135036  30.29365764] the nearest lat_longs are:
# [[30.912765 30.295561]
#  [30.912765 30.295561]
#  [30.915766 30.297315]]
# With distances of:
# [0.19928897 0.19928897 0.43013985]
# -------------------------------------
# Indexes of nearest lat_long [ 40 177 128]
# For lat_long [31.024659 30.607641] the nearest lat_longs are:
# [[31.024659   30.607641  ]
#  [31.02393382 30.60350721]
#  [31.013742   30.57017929]]
# With distances of:
# [0.         0.40207097 3.7706048 ]
# -------------------------------------
# Indexes of nearest lat_long [110 116 198]
# For lat_long [31.18275058 30.52755669] the nearest lat_longs are:
# [[31.1824926  30.52713284]
#  [31.1838385  30.52745446]
#  [31.18416312 30.52710423]]
# With distances of:
# [0.04948385 0.1213617  0.16285831]
# -------------------------------------
# Indexes of nearest lat_long [42 80 87]
# For lat_long [30.763683 30.704811] the nearest lat_longs are:
# [[30.763683   30.704811  ]
#  [30.7637539  30.69974764]
#  [30.760111   30.694501  ]]
# With distances of:
# [0.         0.48385843 1.06217578]
# -------------------------------------
# Indexes of nearest lat_long [  38  190 3350]
# For lat_long [31.103395 30.638362] the nearest lat_longs are:
# [[31.10691837 30.64172916]
#  [31.10958367 30.63910172]
#  [31.12534257 30.64901408]]
# With distances of:
# [0.50622396 0.69174304 2.64275438]
# -------------------------------------
# Indexes of nearest lat_long [145  72  83]
# For lat_long [30.886466 30.662967] the nearest lat_longs are:
# [[30.886466   30.662967  ]
#  [30.88483388 30.66364617]
#  [30.884864   30.665297  ]]
# With distances of:
# [0.         0.19270895 0.28490142]
# -------------------------------------
# Indexes of nearest lat_long [162 180  60]
# For lat_long [30.571713 30.711668] the nearest lat_longs are:
# [[30.571713   30.711668  ]
#  [30.5761452  30.7090382 ]
#  [30.57726731 30.71009132]]
# With distances of:
# [0.         0.5534218  0.63578856]
# -------------------------------------
# Indexes of nearest lat_long [153  39 191]
# For lat_long [30.912765 30.295561] the nearest lat_longs are:
# [[30.912765   30.295561  ]
#  [30.9135036  30.29365764]
#  [30.91038848 30.29732155]]
# With distances of:
# [0.         0.19928897 0.31311606]
# -------------------------------------
# Indexes of nearest lat_long [ 47 175 149]
# For lat_long [31.026177 30.451221] the nearest lat_longs are:
# [[31.026177   30.451221  ]
#  [31.02842246 30.44735618]
#  [31.036522   30.456495  ]]
# With distances of:
# [0.         0.44492467 1.25528344]
# -------------------------------------
# Indexes of nearest lat_long [ 48 193 192]
# For lat_long [30.912211 30.170589] the nearest lat_longs are:
# [[30.912211   30.170589  ]
#  [30.91144225 30.17490715]
#  [30.91290404 30.17689168]]
# With distances of:
# [0.         0.42072968 0.60619359]
# -------------------------------------
# Indexes of nearest lat_long [ 49 194  82]
# For lat_long [30.829702 30.535141] the nearest lat_longs are:
# [[30.829702   30.535141  ]
#  [30.82955574 30.53589971]
#  [30.82785    30.536831  ]]
# With distances of:
# [0.         0.07424665 0.26162507]
# -------------------------------------
# Indexes of nearest lat_long [187  59 132]
# For lat_long [31.099697 30.311892] the nearest lat_longs are:
# [[31.099697   30.311892  ]
#  [31.0978262  30.31474322]
#  [31.100602   30.31555   ]]
# With distances of:
# [0.         0.34201264 0.36253345]
# -------------------------------------
# Indexes of nearest lat_long [163  60 180]
# For lat_long [30.57747  30.710336] the nearest lat_longs are:
# [[30.57747    30.710336  ]
#  [30.57726731 30.71009132]
#  [30.5761452  30.7090382 ]]
# With distances of:
# [0.         0.03250654 0.19270886]
# -------------------------------------
# Indexes of nearest lat_long [ 52 117 188]
# For lat_long [31.051574 30.463915] the nearest lat_longs are:
# [[31.051574   30.463915  ]
#  [31.05193166 30.46430279]
#  [31.052879   30.462731  ]]
# With distances of:
# [0.         0.05427987 0.18378776]
# -------------------------------------
# Indexes of nearest lat_long [181  64  70]
# For lat_long [30.67059438 30.07277643] the nearest lat_longs are:
# [[30.671835 30.073109]
#  [30.671835 30.073109]
#  [30.662002 30.08606 ]]
# With distances of:
# [0.14156972 0.14156972 1.58966042]
# -------------------------------------
# Indexes of nearest lat_long [164 160  92]
# For lat_long [30.663293 30.566847] the nearest lat_longs are:
# [[30.663293 30.566847]
#  [30.699037 30.668604]
#  [30.699037 30.668604]]
# With distances of:
# [ 0.         10.51140195 10.51140195]
# -------------------------------------
# Indexes of nearest lat_long [ 55  59 187]
# For lat_long [31.100602 30.31555 ] the nearest lat_longs are:
# [[31.100602   30.31555   ]
#  [31.0978262  30.31474322]
#  [31.099697   30.311892  ]]
# With distances of:
# [0.         0.31807022 0.36253345]
# -------------------------------------
# Indexes of nearest lat_long [125 157  81]
# For lat_long [30.768322 30.594444] the nearest lat_longs are:
# [[30.76832208 30.59444399]
#  [30.827806   30.536877  ]
#  [30.827806   30.536877  ]]
# With distances of:
# [8.94675635e-06 8.60128780e+00 8.60128780e+00]
# -------------------------------------
# Indexes of nearest lat_long [ 57 119 189]
# For lat_long [31.032701 30.464771] the nearest lat_longs are:
# [[31.032701   30.464771  ]
#  [31.03428061 30.46823018]
#  [31.036388   30.457638  ]]
# With distances of:
# [0.         0.37346905 0.79370128]
# -------------------------------------
# Indexes of nearest lat_long [131 156  96]
# For lat_long [31.1033   30.310782] the nearest lat_longs are:
# [[31.1033   30.310782]
#  [31.105004 30.314502]
#  [31.105004 30.314502]]
# With distances of:
# [0.         0.40167313 0.40167313]
# -------------------------------------
# Indexes of nearest lat_long [ 55 132  50]
# For lat_long [31.0978262  30.31474322] the nearest lat_longs are:
# [[31.100602 30.31555 ]
#  [31.100602 30.31555 ]
#  [31.099697 30.311892]]
# With distances of:
# [0.31807022 0.31807022 0.34201264]
# -------------------------------------
# Indexes of nearest lat_long [ 51 163 180]
# For lat_long [30.57726731 30.71009132] the nearest lat_longs are:
# [[30.57747   30.710336 ]
#  [30.57747   30.710336 ]
#  [30.5761452 30.7090382]]
# With distances of:
# [0.03250654 0.03250654 0.16041349]
# -------------------------------------
# Indexes of nearest lat_long [189 149  94]
# For lat_long [31.036388 30.457638] the nearest lat_longs are:
# [[31.036388 30.457638]
#  [31.036522 30.456495]
#  [31.036522 30.456495]]
# With distances of:
# [0.         0.10991531 0.10991531]
# -------------------------------------
# Indexes of nearest lat_long [174 175  65]
# For lat_long [31.037774 30.433125] the nearest lat_longs are:
# [[31.037774   30.433125  ]
#  [31.02842246 30.44735618]
#  [31.03936    30.455253  ]]
# With distances of:
# [0.         1.7087568  2.11558822]
# -------------------------------------
# Indexes of nearest lat_long [ 63 117  52]
# For lat_long [31.052879 30.462731] the nearest lat_longs are:
# [[31.052879   30.462731  ]
#  [31.05193166 30.46430279]
#  [31.051574   30.463915  ]]
# With distances of:
# [0.         0.18307154 0.18378776]
# -------------------------------------
# Indexes of nearest lat_long [181  53  70]
# For lat_long [30.671835 30.073109] the nearest lat_longs are:
# [[30.671835   30.073109  ]
#  [30.67059438 30.07277643]
#  [30.662002   30.08606   ]]
# With distances of:
# [0.         0.14156972 1.65221667]
# -------------------------------------
# Indexes of nearest lat_long [ 65 122 139]
# For lat_long [31.03936  30.455253] the nearest lat_longs are:
# [[31.03936    30.455253  ]
#  [31.03732147 30.45559064]
#  [31.03975    30.458095  ]]
# With distances of:
# [0.         0.2289454  0.27421691]
# -------------------------------------
# Indexes of nearest lat_long [139  65 137]
# For lat_long [31.03975  30.458095] the nearest lat_longs are:
# [[31.03975  30.458095]
#  [31.03936  30.455253]
#  [31.03936  30.455253]]
# With distances of:
# [0.         0.27421691 0.27421691]
# -------------------------------------
# Indexes of nearest lat_long [ 85 170 123]
# For lat_long [31.40631062 30.4238614 ] the nearest lat_longs are:
# [[31.40487    30.423086  ]
#  [31.40487    30.423086  ]
#  [31.40949916 30.42373416]]
# With distances of:
# [0.17628389 0.17628389 0.35475527]
# -------------------------------------
# Indexes of nearest lat_long [197  89 146]
# For lat_long [31.03052168 30.71357679] the nearest lat_longs are:
# [[31.02893672 30.71354872]
#  [31.027977   30.711581  ]
#  [31.027977   30.711581  ]]
# With distances of:
# [0.17625937 0.34092036 0.34092036]
# -------------------------------------
# Indexes of nearest lat_long [ 69 120 182]
# For lat_long [30.632194 30.2275  ] the nearest lat_longs are:
# [[30.632194  30.2275   ]
#  [30.7009946 30.2682834]
#  [30.662002  30.08606  ]]
# With distances of:
# [ 0.          8.58732792 13.9307057 ]
# -------------------------------------
# Indexes of nearest lat_long [182  53  64]
# For lat_long [30.662002 30.08606 ] the nearest lat_longs are:
# [[30.662002   30.08606   ]
#  [30.67059438 30.07277643]
#  [30.671835   30.073109  ]]
# With distances of:
# [0.         1.58966042 1.65221667]
# -------------------------------------
# Indexes of nearest lat_long [118 140  76]
# For lat_long [31.044442 30.470853] the nearest lat_longs are:
# [[31.04444207 30.47085251]
#  [31.04241948 30.46890924]
#  [31.04241948 30.46890924]]
# With distances of:
# [4.73258929e-05 2.91323033e-01 2.91323507e-01]
# -------------------------------------
# Indexes of nearest lat_long [ 83  44 145]
# For lat_long [30.88483388 30.66364617] the nearest lat_longs are:
# [[30.884864 30.665297]
#  [30.886466 30.662967]
#  [30.886466 30.662967]]
# With distances of:
# [0.15757038 0.19270895 0.19270895]
# -------------------------------------
# Indexes of nearest lat_long [114 193 192]
# For lat_long [30.91078908 30.17701905] the nearest lat_longs are:
# [[30.91158881 30.17717889]
#  [30.91144225 30.17490715]
#  [30.91290404 30.17689168]]
# With distances of:
# [0.09022356 0.21416911 0.2354862 ]
# -------------------------------------
# Indexes of nearest lat_long [ 75 119 106]
# For lat_long [31.03450281 30.47469798] the nearest lat_longs are:
# [[31.03449464 30.47471262]
#  [31.03428061 30.46823018]
#  [31.041921   30.473102  ]]
# With distances of:
# [0.00166475 0.61673596 0.83876286]
# -------------------------------------
# Indexes of nearest lat_long [ 74 119 106]
# For lat_long [31.03449464 30.47471262] the nearest lat_longs are:
# [[31.03450281 30.47469798]
#  [31.03428061 30.46823018]
#  [31.041921   30.473102  ]]
# With distances of:
# [0.00166475 0.61809378 0.83991061]
# -------------------------------------
# Indexes of nearest lat_long [140 109 136]
# For lat_long [31.04241948 30.46890924] the nearest lat_longs are:
# [[31.04241948 30.46890924]
#  [31.040307   30.468207  ]
#  [31.040307   30.468207  ]]
# With distances of:
# [5.25693289e-07 2.44238639e-01 2.44238639e-01]
# -------------------------------------
# Indexes of nearest lat_long [196 112  64]
# For lat_long [30.81405902 29.98830245] the nearest lat_longs are:
# [[30.92230447 29.95121672]
#  [30.8601142  30.15493118]
#  [30.671835   30.073109  ]]
# With distances of:
# [12.54601409 16.71282733 17.77047276]
# -------------------------------------
# Indexes of nearest lat_long [ 84 151 153]
# For lat_long [30.91770833 30.30043628] the nearest lat_longs are:
# [[30.915766 30.297315]
#  [30.915766 30.297315]
#  [30.912765 30.295561]]
# With distances of:
# [0.36783874 0.36783874 0.72003333]
# -------------------------------------
# Indexes of nearest lat_long [173  86 130]
# For lat_long [31.13386822 30.13512986] the nearest lat_longs are:
# [[31.135432 30.129149]
#  [31.135432 30.129149]
#  [31.130591 30.122248]]
# With distances of:
# [0.59521059 0.59521059 1.27910576]
# -------------------------------------
# Indexes of nearest lat_long [ 42 184  87]
# For lat_long [30.7637539  30.69974764] the nearest lat_longs are:
# [[30.763683 30.704811]
#  [30.763683 30.704811]
#  [30.760111 30.694501]]
# With distances of:
# [0.48385843 0.48385843 0.64451542]
# -------------------------------------
# Indexes of nearest lat_long [157  82 168]
# For lat_long [30.827806 30.536877] the nearest lat_longs are:
# [[30.827806 30.536877]
#  [30.82785  30.536831]
#  [30.82785  30.536831]]
# With distances of:
# [0.         0.00657491 0.00657491]
# -------------------------------------
# Indexes of nearest lat_long [168  81 157]
# For lat_long [30.82785  30.536831] the nearest lat_longs are:
# [[30.82785  30.536831]
#  [30.827806 30.536877]
#  [30.827806 30.536877]]
# With distances of:
# [0.         0.00657491 0.00657491]
# -------------------------------------
# Indexes of nearest lat_long [ 72 138  93]
# For lat_long [30.884864 30.665297] the nearest lat_longs are:
# [[30.88483388 30.66364617]
#  [30.88655    30.667319  ]
#  [30.886553   30.667319  ]]
# With distances of:
# [0.15757038 0.26903072 0.26926328]
# -------------------------------------
# Indexes of nearest lat_long [151  78 153]
# For lat_long [30.915766 30.297315] the nearest lat_longs are:
# [[30.915766   30.297315  ]
#  [30.91770833 30.30043628]
#  [30.912765   30.295561  ]]
# With distances of:
# [0.         0.36783874 0.37329859]
# -------------------------------------
# Indexes of nearest lat_long [170  67 123]
# For lat_long [31.40487  30.423086] the nearest lat_longs are:
# [[31.40487    30.423086  ]
#  [31.40631062 30.4238614 ]
#  [31.40949916 30.42373416]]
# With distances of:
# [0.         0.17628389 0.51840152]
# -------------------------------------
# Indexes of nearest lat_long [173  79  99]
# For lat_long [31.135432 30.129149] the nearest lat_longs are:
# [[31.135432   30.129149  ]
#  [31.13386822 30.13512986]
#  [31.139143   30.12155   ]]
# With distances of:
# [0.         0.59521059 0.83267383]
# -------------------------------------
# Indexes of nearest lat_long [87 80 42]
# For lat_long [30.760111 30.694501] the nearest lat_longs are:
# [[30.760111   30.694501  ]
#  [30.7637539  30.69974764]
#  [30.763683   30.704811  ]]
# With distances of:
# [0.         0.64451542 1.06217578]
# -------------------------------------
# Indexes of nearest lat_long [142 127 463]
# For lat_long [30.395427 30.37151 ] the nearest lat_longs are:
# [[30.395427   30.37151   ]
#  [30.39499563 30.37081886]
#  [30.3728385  30.49884544]]
# With distances of:
# [ 0.          0.08182249 12.46993938]
# -------------------------------------
# Indexes of nearest lat_long [ 89 197  68]
# For lat_long [31.027977 30.711581] the nearest lat_longs are:
# [[31.027977   30.711581  ]
#  [31.02893672 30.71354872]
#  [31.03052168 30.71357679]]
# With distances of:
# [0.         0.21573546 0.34092036]
# -------------------------------------
# Indexes of nearest lat_long [133 116 198]
# For lat_long [31.184945 30.52952 ] the nearest lat_longs are:
# [[31.184945   30.52952   ]
#  [31.1838385  30.52745446]
#  [31.18416312 30.52710423]]
# With distances of:
# [0.         0.23183318 0.24570274]
# -------------------------------------
# Indexes of nearest lat_long [134 110  41]
# For lat_long [31.175947 30.529477] the nearest lat_longs are:
# [[31.175947   30.529477  ]
#  [31.1824926  30.52713284]
#  [31.18275058 30.52755669]]
# With distances of:
# [0.         0.76123558 0.77826809]
# -------------------------------------
# Indexes of nearest lat_long [ 92 126 159]
# For lat_long [30.699037 30.668604] the nearest lat_longs are:
# [[30.699037   30.668604  ]
#  [30.69531566 30.73931943]
#  [30.760111   30.694501  ]]
# With distances of:
# [0.         6.77403575 7.22816214]
# -------------------------------------
# Indexes of nearest lat_long [138  83  72]
# For lat_long [30.886553 30.667319] the nearest lat_longs are:
# [[30.88655    30.667319  ]
#  [30.884864   30.665297  ]
#  [30.88483388 30.66364617]]
# With distances of:
# [3.33584780e-04 2.69263279e-01 3.99226489e-01]
# -------------------------------------
# Indexes of nearest lat_long [149  61 189]
# For lat_long [31.036522 30.456495] the nearest lat_longs are:
# [[31.036522 30.456495]
#  [31.036388 30.457638]
#  [31.036388 30.457638]]
# With distances of:
# [0.         0.10991531 0.10991531]
# -------------------------------------
# Indexes of nearest lat_long [ 95 106 154]
# For lat_long [31.04408  30.475274] the nearest lat_longs are:
# [[31.04408  30.475274]
#  [31.041921 30.473102]
#  [31.041921 30.473102]]
# With distances of:
# [0.         0.31694127 0.31694127]
# -------------------------------------
# Indexes of nearest lat_long [156 131  58]
# For lat_long [31.105004 30.314502] the nearest lat_longs are:
# [[31.105004 30.314502]
#  [31.1033   30.310782]
#  [31.1033   30.310782]]
# With distances of:
# [0.         0.40167313 0.40167313]
# -------------------------------------
# Indexes of nearest lat_long [ 97  89 146]
# For lat_long [31.027458 30.704211] the nearest lat_longs are:
# [[31.027458 30.704211]
#  [31.027977 30.711581]
#  [31.027977 30.711581]]
# With distances of:
# [0.         0.70461729 0.70461729]
# -------------------------------------
# Indexes of nearest lat_long [143  98 167]
# For lat_long [31.139199 30.121385] the nearest lat_longs are:
# [[31.139199 30.121385]
#  [31.139199 30.121385]
#  [31.139143 30.12155 ]]
# With distances of:
# [0.         0.         0.01689311]
# -------------------------------------
# Indexes of nearest lat_long [ 99 144 143]
# For lat_long [31.139143 30.12155 ] the nearest lat_longs are:
# [[31.139143 30.12155 ]
#  [31.139199 30.121385]
#  [31.139199 30.121385]]
# With distances of:
# [0.         0.01689311 0.01689311]
# -------------------------------------
# Indexes of nearest lat_long [100 124  85]
# For lat_long [31.392898 30.414696] the nearest lat_longs are:
# [[31.392898   30.414696  ]
#  [31.39517685 30.42186514]
#  [31.40487    30.423086  ]]
# With distances of:
# [0.         0.72611931 1.55121544]
# -------------------------------------
# Indexes of nearest lat_long [169 115 158]
# For lat_long [30.833752 30.530286] the nearest lat_longs are:
# [[30.833752   30.530286  ]
#  [30.82974495 30.52961337]
#  [30.829702   30.535141  ]]
# With distances of:
# [0.         0.45016835 0.64629035]
# -------------------------------------
# Indexes of nearest lat_long [102  86 173]
# For lat_long [31.130591 30.122248] the nearest lat_longs are:
# [[31.130591 30.122248]
#  [31.135432 30.129149]
#  [31.135432 30.129149]]
# With distances of:
# [0.         0.84922976 0.84922976]
# -------------------------------------
# Indexes of nearest lat_long [103 198 110]
# For lat_long [31.183878 30.519738] the nearest lat_longs are:
# [[31.183878   30.519738  ]
#  [31.18416312 30.52710423]
#  [31.1824926  30.52713284]]
# With distances of:
# [0.         0.70145324 0.72013412]
# -------------------------------------
# Indexes of nearest lat_long [104 192 114]
# For lat_long [30.91584  30.176447] the nearest lat_longs are:
# [[30.91584    30.176447  ]
#  [30.91290404 30.17689168]
#  [30.91158881 30.17717889]]
# With distances of:
# [0.         0.32920851 0.4778394 ]
# -------------------------------------
# Indexes of nearest lat_long [ 105 3321 3322]
# For lat_long [31.288168 30.513992] the nearest lat_longs are:
# [[31.288168   30.513992  ]
#  [31.29008495 30.52348558]
#  [31.28994018 30.52365427]]
# With distances of:
# [0.         0.926944   0.93904167]
# -------------------------------------
# Indexes of nearest lat_long [154  95 155]
# For lat_long [31.041921 30.473102] the nearest lat_longs are:
# [[31.041921 30.473102]
#  [31.04408  30.475274]
#  [31.04408  30.475274]]
# With distances of:
# [0.         0.31694127 0.31694127]
# -------------------------------------
# Indexes of nearest lat_long [185 179  72]
# For lat_long [30.880486 30.653383] the nearest lat_longs are:
# [[30.880486   30.653383  ]
#  [30.88563219 30.65812817]
#  [30.88483388 30.66364617]]
# With distances of:
# [0.         0.72972669 1.09223743]
# -------------------------------------
# Indexes of nearest lat_long [108 100 171]
# For lat_long [31.301812 30.301819] the nearest lat_longs are:
# [[31.301812 30.301819]
#  [31.392898 30.414696]
#  [31.392898 30.414696]]
# With distances of:
# [ 0.        14.7473411 14.7473411]
# -------------------------------------
# Indexes of nearest lat_long [109  76 140]
# For lat_long [31.040307 30.468207] the nearest lat_longs are:
# [[31.040307   30.468207  ]
#  [31.04241948 30.46890924]
#  [31.04241948 30.46890924]]
# With distances of:
# [0.         0.24423864 0.24423898]
# -------------------------------------
# Indexes of nearest lat_long [ 41 116 198]
# For lat_long [31.1824926  30.52713284] the nearest lat_longs are:
# [[31.18275058 30.52755669]
#  [31.1838385  30.52745446]
#  [31.18416312 30.52710423]]
# With distances of:
# [0.04948385 0.15275265 0.18577329]
# -------------------------------------
# Indexes of nearest lat_long [129 200  76]
# For lat_long [31.04438807 30.4667885 ] the nearest lat_longs are:
# [[31.0463062  30.4652941 ]
#  [31.046464   30.46865632]
#  [31.04241948 30.46890924]]
# With distances of:
# [0.25643624 0.291457   0.29788686]
# -------------------------------------
# Indexes of nearest lat_long [113  48 161]
# For lat_long [30.8601142  30.15493118] the nearest lat_longs are:
# [[30.9063534 30.1736873]
#  [30.912211  30.170589 ]
#  [30.912211  30.170589 ]]
# With distances of:
# [5.44420412 5.9824931  5.9824931 ]
# -------------------------------------
# Indexes of nearest lat_long [193  73 114]
# For lat_long [30.9063534 30.1736873] the nearest lat_longs are:
# [[30.91144225 30.17490715]
#  [30.91078908 30.17701905]
#  [30.91158881 30.17717889]]
# With distances of:
# [0.57769797 0.5867773  0.67071759]
# -------------------------------------
# Indexes of nearest lat_long [ 73 192 193]
# For lat_long [30.91158881 30.17717889] the nearest lat_longs are:
# [[30.91078908 30.17701905]
#  [30.91290404 30.17689168]
#  [30.91144225 30.17490715]]
# With distances of:
# [0.09022356 0.1487915  0.21733809]
# -------------------------------------
# Indexes of nearest lat_long [169 101  49]
# For lat_long [30.82974495 30.52961337] the nearest lat_longs are:
# [[30.833752 30.530286]
#  [30.833752 30.530286]
#  [30.829702 30.535141]]
# With distances of:
# [0.45016835 0.45016835 0.52781317]
# -------------------------------------
# Indexes of nearest lat_long [198  41 110]
# For lat_long [31.1838385  30.52745446] the nearest lat_longs are:
# [[31.18416312 30.52710423]
#  [31.18275058 30.52755669]
#  [31.1824926  30.52713284]]
# With distances of:
# [0.04912164 0.1213617  0.15275265]
# -------------------------------------
# Indexes of nearest lat_long [147  52 188]
# For lat_long [31.05193166 30.46430279] the nearest lat_longs are:
# [[31.051574 30.463915]
#  [31.051574 30.463915]
#  [31.052879 30.462731]]
# With distances of:
# [0.05427987 0.05427987 0.18307154]
# -------------------------------------
# Indexes of nearest lat_long [ 71 140  76]
# For lat_long [31.04444207 30.47085251] the nearest lat_longs are:
# [[31.044442   30.470853  ]
#  [31.04241948 30.46890924]
#  [31.04241948 30.46890924]]
# With distances of:
# [4.73258929e-05 2.91299371e-01 2.91299846e-01]
# -------------------------------------
# Indexes of nearest lat_long [ 57 150  74]
# For lat_long [31.03428061 30.46823018] the nearest lat_longs are:
# [[31.032701   30.464771  ]
#  [31.032701   30.464771  ]
#  [31.03450281 30.47469798]]
# With distances of:
# [0.37346905 0.37346905 0.61673596]
# -------------------------------------
# Indexes of nearest lat_long [ 69 183  70]
# For lat_long [30.7009946 30.2682834] the nearest lat_longs are:
# [[30.632194 30.2275  ]
#  [30.632194 30.2275  ]
#  [30.662002 30.08606 ]]
# With distances of:
# [ 8.58732792  8.58732792 17.95723406]
# -------------------------------------
# Indexes of nearest lat_long [ 80 184  42]
# For lat_long [30.81082688 30.68590817] the nearest lat_longs are:
# [[30.7637539  30.69974764]
#  [30.763683   30.704811  ]
#  [30.763683   30.704811  ]]
# With distances of:
# [5.39864445 5.54443382 5.54443382]
# -------------------------------------
# Indexes of nearest lat_long [149  94  61]
# For lat_long [31.03732147 30.45559064] the nearest lat_longs are:
# [[31.036522 30.456495]
#  [31.036522 30.456495]
#  [31.036388 30.457638]]
# With distances of:
# [0.1238016  0.1238016  0.22096097]
# -------------------------------------
# Indexes of nearest lat_long [ 67  85 170]
# For lat_long [31.40949916 30.42373416] the nearest lat_longs are:
# [[31.40631062 30.4238614 ]
#  [31.40487    30.423086  ]
#  [31.40487    30.423086  ]]
# With distances of:
# [0.35475527 0.51840152 0.51840152]
# -------------------------------------
# Indexes of nearest lat_long [100 171 170]
# For lat_long [31.39517685 30.42186514] the nearest lat_longs are:
# [[31.392898 30.414696]
#  [31.392898 30.414696]
#  [31.40487  30.423086]]
# With distances of:
# [0.72611931 0.72611931 1.08403966]
# -------------------------------------
# Indexes of nearest lat_long [ 56 157  81]
# For lat_long [30.76832208 30.59444399] the nearest lat_longs are:
# [[30.768322 30.594444]
#  [30.827806 30.536877]
#  [30.827806 30.536877]]
# With distances of:
# [8.94675635e-06 8.60128035e+00 8.60128035e+00]
# -------------------------------------
# Indexes of nearest lat_long [199  92 160]
# For lat_long [30.69531566 30.73931943] the nearest lat_longs are:
# [[30.73383215 30.77503088]
#  [30.699037   30.668604  ]
#  [30.699037   30.668604  ]]
# With distances of:
# [5.47698916 6.77403575 6.77403575]
# -------------------------------------
# Indexes of nearest lat_long [ 88 142 463]
# For lat_long [30.39499563 30.37081886] the nearest lat_longs are:
# [[30.395427   30.37151   ]
#  [30.395427   30.37151   ]
#  [30.3728385  30.49884544]]
# With distances of:
# [ 0.08182249  0.08182249 12.52538707]
# -------------------------------------
# Indexes of nearest lat_long [177  40 152]
# For lat_long [31.013742   30.57017929] the nearest lat_longs are:
# [[31.02393382 30.60350721]
#  [31.024659   30.607641  ]
#  [31.024659   30.607641  ]]
# With distances of:
# [3.37208333 3.7706048  3.7706048 ]
# -------------------------------------
# Indexes of nearest lat_long [111 200  76]
# For lat_long [31.0463062 30.4652941] the nearest lat_longs are:
# [[31.04438807 30.4667885 ]
#  [31.046464   30.46865632]
#  [31.04241948 30.46890924]]
# With distances of:
# [0.25643624 0.32078637 0.5526296 ]
# -------------------------------------
# Indexes of nearest lat_long [102  86 173]
# For lat_long [31.130591 30.122248] the nearest lat_longs are:
# [[31.130591 30.122248]
#  [31.135432 30.129149]
#  [31.135432 30.129149]]
# With distances of:
# [0.         0.84922976 0.84922976]
# -------------------------------------
# Indexes of nearest lat_long [131 156  96]
# For lat_long [31.1033   30.310782] the nearest lat_longs are:
# [[31.1033   30.310782]
#  [31.105004 30.314502]
#  [31.105004 30.314502]]
# With distances of:
# [0.         0.40167313 0.40167313]
# -------------------------------------
# Indexes of nearest lat_long [ 55  59 187]
# For lat_long [31.100602 30.31555 ] the nearest lat_longs are:
# [[31.100602   30.31555   ]
#  [31.0978262  30.31474322]
#  [31.099697   30.311892  ]]
# With distances of:
# [0.         0.31807022 0.36253345]
# -------------------------------------
# Indexes of nearest lat_long [133 116 198]
# For lat_long [31.184945 30.52952 ] the nearest lat_longs are:
# [[31.184945   30.52952   ]
#  [31.1838385  30.52745446]
#  [31.18416312 30.52710423]]
# With distances of:
# [0.         0.23183318 0.24570274]
# -------------------------------------
# Indexes of nearest lat_long [134 110  41]
# For lat_long [31.175947 30.529477] the nearest lat_longs are:
# [[31.175947   30.529477  ]
#  [31.1824926  30.52713284]
#  [31.18275058 30.52755669]]
# With distances of:
# [0.         0.76123558 0.77826809]
# -------------------------------------
# Indexes of nearest lat_long [103 198 110]
# For lat_long [31.183878 30.519738] the nearest lat_longs are:
# [[31.183878   30.519738  ]
#  [31.18416312 30.52710423]
#  [31.1824926  30.52713284]]
# With distances of:
# [0.         0.70145324 0.72013412]
# -------------------------------------
# Indexes of nearest lat_long [109  76 140]
# For lat_long [31.040307 30.468207] the nearest lat_longs are:
# [[31.040307   30.468207  ]
#  [31.04241948 30.46890924]
#  [31.04241948 30.46890924]]
# With distances of:
# [0.         0.24423864 0.24423898]
# -------------------------------------
# Indexes of nearest lat_long [ 65 122 139]
# For lat_long [31.03936  30.455253] the nearest lat_longs are:
# [[31.03936    30.455253  ]
#  [31.03732147 30.45559064]
#  [31.03975    30.458095  ]]
# With distances of:
# [0.         0.2289454  0.27421691]
# -------------------------------------
# Indexes of nearest lat_long [93 83 72]
# For lat_long [30.88655  30.667319] the nearest lat_longs are:
# [[30.886553   30.667319  ]
#  [30.884864   30.665297  ]
#  [30.88483388 30.66364617]]
# With distances of:
# [3.33584780e-04 2.69030716e-01 3.99066874e-01]
# -------------------------------------
# Indexes of nearest lat_long [139  65 137]
# For lat_long [31.03975  30.458095] the nearest lat_longs are:
# [[31.03975  30.458095]
#  [31.03936  30.455253]
#  [31.03936  30.455253]]
# With distances of:
# [0.         0.27421691 0.27421691]
# -------------------------------------
# Indexes of nearest lat_long [ 76 109 136]
# For lat_long [31.04241948 30.46890924] the nearest lat_longs are:
# [[31.04241948 30.46890924]
#  [31.040307   30.468207  ]
#  [31.040307   30.468207  ]]
# With distances of:
# [5.25693289e-07 2.44238983e-01 2.44238983e-01]
# -------------------------------------
# Indexes of nearest lat_long [195 138  93]
# For lat_long [30.86942495 30.70074488] the nearest lat_longs are:
# [[30.88808594 30.67314422]
#  [30.88655    30.667319  ]
#  [30.886553   30.667319  ]]
# With distances of:
# [3.35317401 3.71510597 3.71527692]
# -------------------------------------
# Indexes of nearest lat_long [142 127 463]
# For lat_long [30.395427 30.37151 ] the nearest lat_longs are:
# [[30.395427   30.37151   ]
#  [30.39499563 30.37081886]
#  [30.3728385  30.49884544]]
# With distances of:
# [ 0.          0.08182249 12.46993938]
# -------------------------------------
# Indexes of nearest lat_long [143  98 167]
# For lat_long [31.139199 30.121385] the nearest lat_longs are:
# [[31.139199 30.121385]
#  [31.139199 30.121385]
#  [31.139143 30.12155 ]]
# With distances of:
# [0.         0.         0.01689311]
# -------------------------------------
# Indexes of nearest lat_long [143  98 167]
# For lat_long [31.139199 30.121385] the nearest lat_longs are:
# [[31.139199 30.121385]
#  [31.139199 30.121385]
#  [31.139143 30.12155 ]]
# With distances of:
# [0.         0.         0.01689311]
# -------------------------------------
# Indexes of nearest lat_long [145  72  83]
# For lat_long [30.886466 30.662967] the nearest lat_longs are:
# [[30.886466   30.662967  ]
#  [30.88483388 30.66364617]
#  [30.884864   30.665297  ]]
# With distances of:
# [0.         0.19270895 0.28490142]
# -------------------------------------
# Indexes of nearest lat_long [ 89 197  68]
# For lat_long [31.027977 30.711581] the nearest lat_longs are:
# [[31.027977   30.711581  ]
#  [31.02893672 30.71354872]
#  [31.03052168 30.71357679]]
# With distances of:
# [0.         0.21573546 0.34092036]
# -------------------------------------
# Indexes of nearest lat_long [ 52 117 188]
# For lat_long [31.051574 30.463915] the nearest lat_longs are:
# [[31.051574   30.463915  ]
#  [31.05193166 30.46430279]
#  [31.052879   30.462731  ]]
# With distances of:
# [0.         0.05427987 0.18378776]
# -------------------------------------
# Indexes of nearest lat_long [ 47 175 149]
# For lat_long [31.026177 30.451221] the nearest lat_longs are:
# [[31.026177   30.451221  ]
#  [31.02842246 30.44735618]
#  [31.036522   30.456495  ]]
# With distances of:
# [0.         0.44492467 1.25528344]
# -------------------------------------
# Indexes of nearest lat_long [149  61 189]
# For lat_long [31.036522 30.456495] the nearest lat_longs are:
# [[31.036522 30.456495]
#  [31.036388 30.457638]
#  [31.036388 30.457638]]
# With distances of:
# [0.         0.10991531 0.10991531]
# -------------------------------------
# Indexes of nearest lat_long [ 57 119 189]
# For lat_long [31.032701 30.464771] the nearest lat_longs are:
# [[31.032701   30.464771  ]
#  [31.03428061 30.46823018]
#  [31.036388   30.457638  ]]
# With distances of:
# [0.         0.37346905 0.79370128]
# -------------------------------------
# Indexes of nearest lat_long [151  78 153]
# For lat_long [30.915766 30.297315] the nearest lat_longs are:
# [[30.915766   30.297315  ]
#  [30.91770833 30.30043628]
#  [30.912765   30.295561  ]]
# With distances of:
# [0.         0.36783874 0.37329859]
# -------------------------------------
# Indexes of nearest lat_long [ 40 177 128]
# For lat_long [31.024659 30.607641] the nearest lat_longs are:
# [[31.024659   30.607641  ]
#  [31.02393382 30.60350721]
#  [31.013742   30.57017929]]
# With distances of:
# [0.         0.40207097 3.7706048 ]
# -------------------------------------
# Indexes of nearest lat_long [153  39 191]
# For lat_long [30.912765 30.295561] the nearest lat_longs are:
# [[30.912765   30.295561  ]
#  [30.9135036  30.29365764]
#  [30.91038848 30.29732155]]
# With distances of:
# [0.         0.19928897 0.31311606]
# -------------------------------------
# Indexes of nearest lat_long [154  95 155]
# For lat_long [31.041921 30.473102] the nearest lat_longs are:
# [[31.041921 30.473102]
#  [31.04408  30.475274]
#  [31.04408  30.475274]]
# With distances of:
# [0.         0.31694127 0.31694127]
# -------------------------------------
# Indexes of nearest lat_long [ 95 106 154]
# For lat_long [31.04408  30.475274] the nearest lat_longs are:
# [[31.04408  30.475274]
#  [31.041921 30.473102]
#  [31.041921 30.473102]]
# With distances of:
# [0.         0.31694127 0.31694127]
# -------------------------------------
# Indexes of nearest lat_long [156 131  58]
# For lat_long [31.105004 30.314502] the nearest lat_longs are:
# [[31.105004 30.314502]
#  [31.1033   30.310782]
#  [31.1033   30.310782]]
# With distances of:
# [0.         0.40167313 0.40167313]
# -------------------------------------
# Indexes of nearest lat_long [157  82 168]
# For lat_long [30.827806 30.536877] the nearest lat_longs are:
# [[30.827806 30.536877]
#  [30.82785  30.536831]
#  [30.82785  30.536831]]
# With distances of:
# [0.         0.00657491 0.00657491]
# -------------------------------------
# Indexes of nearest lat_long [ 49 194  82]
# For lat_long [30.829702 30.535141] the nearest lat_longs are:
# [[30.829702   30.535141  ]
#  [30.82955574 30.53589971]
#  [30.82785    30.536831  ]]
# With distances of:
# [0.         0.07424665 0.26162507]
# -------------------------------------
# Indexes of nearest lat_long [87 80 42]
# For lat_long [30.760111 30.694501] the nearest lat_longs are:
# [[30.760111   30.694501  ]
#  [30.7637539  30.69974764]
#  [30.763683   30.704811  ]]
# With distances of:
# [0.         0.64451542 1.06217578]
# -------------------------------------
# Indexes of nearest lat_long [ 92 126 159]
# For lat_long [30.699037 30.668604] the nearest lat_longs are:
# [[30.699037   30.668604  ]
#  [30.69531566 30.73931943]
#  [30.760111   30.694501  ]]
# With distances of:
# [0.         6.77403575 7.22816214]
# -------------------------------------
# Indexes of nearest lat_long [ 48 193 192]
# For lat_long [30.912211 30.170589] the nearest lat_longs are:
# [[30.912211   30.170589  ]
#  [30.91144225 30.17490715]
#  [30.91290404 30.17689168]]
# With distances of:
# [0.         0.42072968 0.60619359]
# -------------------------------------
# Indexes of nearest lat_long [162 180  60]
# For lat_long [30.571713 30.711668] the nearest lat_longs are:
# [[30.571713   30.711668  ]
#  [30.5761452  30.7090382 ]
#  [30.57726731 30.71009132]]
# With distances of:
# [0.         0.5534218  0.63578856]
# -------------------------------------
# Indexes of nearest lat_long [163  60 180]
# For lat_long [30.57747  30.710336] the nearest lat_longs are:
# [[30.57747    30.710336  ]
#  [30.57726731 30.71009132]
#  [30.5761452  30.7090382 ]]
# With distances of:
# [0.         0.03250654 0.19270886]
# -------------------------------------
# Indexes of nearest lat_long [164 160  92]
# For lat_long [30.663293 30.566847] the nearest lat_longs are:
# [[30.663293 30.566847]
#  [30.699037 30.668604]
#  [30.699037 30.668604]]
# With distances of:
# [ 0.         10.51140195 10.51140195]
# -------------------------------------
# Indexes of nearest lat_long [ 97  89 146]
# For lat_long [31.027458 30.704211] the nearest lat_longs are:
# [[31.027458 30.704211]
#  [31.027977 30.711581]
#  [31.027977 30.711581]]
# With distances of:
# [0.         0.70461729 0.70461729]
# -------------------------------------
# Indexes of nearest lat_long [104 192 114]
# For lat_long [30.91584  30.176447] the nearest lat_longs are:
# [[30.91584    30.176447  ]
#  [30.91290404 30.17689168]
#  [30.91158881 30.17717889]]
# With distances of:
# [0.         0.32920851 0.4778394 ]
# -------------------------------------
# Indexes of nearest lat_long [ 99 144 143]
# For lat_long [31.139143 30.12155 ] the nearest lat_longs are:
# [[31.139143 30.12155 ]
#  [31.139199 30.121385]
#  [31.139199 30.121385]]
# With distances of:
# [0.         0.01689311 0.01689311]
# -------------------------------------
# Indexes of nearest lat_long [168  81 157]
# For lat_long [30.82785  30.536831] the nearest lat_longs are:
# [[30.82785  30.536831]
#  [30.827806 30.536877]
#  [30.827806 30.536877]]
# With distances of:
# [0.         0.00657491 0.00657491]
# -------------------------------------
# Indexes of nearest lat_long [169 115 158]
# For lat_long [30.833752 30.530286] the nearest lat_longs are:
# [[30.833752   30.530286  ]
#  [30.82974495 30.52961337]
#  [30.829702   30.535141  ]]
# With distances of:
# [0.         0.45016835 0.64629035]
# -------------------------------------
# Indexes of nearest lat_long [170  67 123]
# For lat_long [31.40487  30.423086] the nearest lat_longs are:
# [[31.40487    30.423086  ]
#  [31.40631062 30.4238614 ]
#  [31.40949916 30.42373416]]
# With distances of:
# [0.         0.17628389 0.51840152]
# -------------------------------------
# Indexes of nearest lat_long [100 124  85]
# For lat_long [31.392898 30.414696] the nearest lat_longs are:
# [[31.392898   30.414696  ]
#  [31.39517685 30.42186514]
#  [31.40487    30.423086  ]]
# With distances of:
# [0.         0.72611931 1.55121544]
# -------------------------------------
# Indexes of nearest lat_long [ 105 3321 3322]
# For lat_long [31.288168 30.513992] the nearest lat_longs are:
# [[31.288168   30.513992  ]
#  [31.29008495 30.52348558]
#  [31.28994018 30.52365427]]
# With distances of:
# [0.         0.926944   0.93904167]
# -------------------------------------
# Indexes of nearest lat_long [173  79  99]
# For lat_long [31.135432 30.129149] the nearest lat_longs are:
# [[31.135432   30.129149  ]
#  [31.13386822 30.13512986]
#  [31.139143   30.12155   ]]
# With distances of:
# ...
# [[30.720512   31.260394  ]
#  [30.72027286 31.25607253]
#  [30.72166318 31.25417092]]
# With distances of:
# [0.         0.4139486  0.60848263]
# -------------------------------------
# Indexes of nearest lat_long [2488 2544 2441]
# For lat_long [31.042415 31.39422 ] the nearest lat_longs are:
# [[31.042415   31.39422   ]
#  [31.04181016 31.39335749]
#  [31.043301   31.392935  ]]
# With distances of:
# [0.         0.10618595 0.15714007]
# -------------------------------------
# Indexes of nearest lat_long [2626 2431 2438]
# For lat_long [31.188486 31.496254] the nearest lat_longs are:
# [[31.188486   31.496254  ]
#  [31.19066798 31.52041102]
#  [31.19066374 31.52048024]]
# With distances of:
# [0.         2.310653   2.31715163]
# -------------------------------------
# Indexes of nearest lat_long [2490 2579 2458]
# For lat_long [30.898103 31.342564] the nearest lat_longs are:
# [[30.898103 31.342564]
#  [30.931001 31.357517]
#  [30.931001 31.357517]]
# With distances of:
# [0.         3.92638368 3.92638368]
# -------------------------------------
# Indexes of nearest lat_long [2407 2587 2509]
# For lat_long [31.11867263 31.6463434 ] the nearest lat_longs are:
# [[31.120718  31.646416 ]
#  [31.120718  31.646416 ]
#  [31.1216098 31.6458735]]
# With distances of:
# [0.22753964 0.22753964 0.32964719]
# -------------------------------------
# Indexes of nearest lat_long [2477 2596  227]
# For lat_long [30.71171694 31.25405897] the nearest lat_longs are:
# [[30.714798   31.252997  ]
#  [30.714798   31.252997  ]
#  [30.71034997 31.25036718]]
# With distances of:
# [0.357324   0.357324   0.38427536]
# -------------------------------------
# Indexes of nearest lat_long [2629 2639 2440]
# For lat_long [31.047391 31.369267] the nearest lat_longs are:
# [[31.047391 31.369267]
#  [31.045989 31.364517]
#  [31.045989 31.364517]]
# With distances of:
# [0.         0.47861426 0.47861426]
# -------------------------------------
# Indexes of nearest lat_long [2577 2514 2476]
# For lat_long [31.0496   31.376869] the nearest lat_longs are:
# [[31.0496     31.376869  ]
#  [31.05021889 31.38009747]
#  [31.050115   31.380445  ]]
# With distances of:
# [0.         0.31515807 0.34543938]
# -------------------------------------
# Indexes of nearest lat_long [2495 2590 2485]
# For lat_long [30.92649  31.306662] the nearest lat_longs are:
# [[30.92649  31.306662]
#  [30.935502 31.290432]
#  [30.935502 31.290432]]
# With distances of:
# [0.         1.84407643 1.84407643]
# -------------------------------------
# Indexes of nearest lat_long [2516 2578 2487]
# For lat_long [30.72027286 31.25607253] the nearest lat_longs are:
# [[30.72166318 31.25417092]
#  [30.720512   31.260394  ]
#  [30.720512   31.260394  ]]
# With distances of:
# [0.23862627 0.4139486  0.4139486 ]
# -------------------------------------
# Indexes of nearest lat_long [2575 2425 2581]
# For lat_long [31.03828145 31.35486177] the nearest lat_longs are:
# [[31.036959 31.358902]
#  [31.036959 31.358902]
#  [31.043345 31.35496 ]]
# With distances of:
# [0.4120644  0.4120644  0.56311884]
# -------------------------------------
# Indexes of nearest lat_long [2408 2607 2515]
# For lat_long [31.12152859 31.44418088] the nearest lat_longs are:
# [[31.119647  31.447351 ]
#  [31.119647  31.447351 ]
#  [31.1297027 31.4219936]]
# With distances of:
# [0.36720481 0.36720481 2.29922064]
# -------------------------------------
# Indexes of nearest lat_long [2411 2460 2611]
# For lat_long [31.158743  31.9355969] the nearest lat_longs are:
# [[31.15821811 31.93456444]
#  [31.160863   31.934843  ]
#  [31.16287    31.930412  ]]
# With distances of:
# [0.11427192 0.24640647 0.67378484]
# -------------------------------------
# Indexes of nearest lat_long [2548 2623 2449]
# For lat_long [31.24902348 31.41450705] the nearest lat_longs are:
# [[31.243739   31.46256849]
#  [31.217524   31.362288  ]
#  [31.217524   31.362288  ]]
# With distances of:
# [4.60661557 6.07606001 6.07606001]
# -------------------------------------
# Indexes of nearest lat_long [2590 2485 2423]
# For lat_long [30.92188868 31.26846548] the nearest lat_longs are:
# [[30.935502   31.290432  ]
#  [30.935502   31.290432  ]
#  [30.93864778 31.29306179]]
# With distances of:
# [2.5848526  2.5848526  2.99611305]
# -------------------------------------
# Indexes of nearest lat_long [2463 2633 2464]
# For lat_long [31.03704574 31.3779531 ] the nearest lat_longs are:
# [[31.040754 31.381102]
#  [31.042824 31.37839 ]
#  [31.042824 31.37839 ]]
# With distances of:
# [0.50992993 0.64386009 0.64386009]
# -------------------------------------
# Indexes of nearest lat_long [2535 2527 2529]
# For lat_long [30.89248985 31.56020697] the nearest lat_longs are:
# [[30.85542672 31.53271891]
#  [30.85079229 31.59031027]
#  [30.87021444 31.50347959]]
# With distances of:
# [4.88537287 5.45456257 5.95328917]
# -------------------------------------
# Indexes of nearest lat_long [2420 2554 2478]
# For lat_long [30.77914964 31.2611899 ] the nearest lat_longs are:
# [[30.77915    31.26119   ]
#  [30.80626811 31.26272928]
#  [30.808291   31.273742  ]]
# With distances of:
# [4.11543408e-05 3.01901919e+00 3.45506846e+00]
# -------------------------------------
# Indexes of nearest lat_long [2506 2433 2466]
# For lat_long [31.03600648 31.39772894] the nearest lat_longs are:
# [[31.035997 31.397656]
#  [31.035997 31.397656]
#  [31.033861 31.395167]]
# With distances of:
# [0.00702897 0.00702897 0.34131617]
# -------------------------------------
# Indexes of nearest lat_long [2433 2505 2466]
# For lat_long [31.035997 31.397656] the nearest lat_longs are:
# [[31.035997   31.397656  ]
#  [31.03600648 31.39772894]
#  [31.033861   31.395167  ]]
# With distances of:
# [0.         0.00702897 0.33563443]
# -------------------------------------
# Indexes of nearest lat_long [2625 2453 2438]
# For lat_long [31.19288865 31.52810955] the nearest lat_longs are:
# [[31.188945   31.526464  ]
#  [31.188945   31.526464  ]
#  [31.19066374 31.52048024]]
# With distances of:
# [0.46561258 0.46561258 0.76671485]
# -------------------------------------
# Indexes of nearest lat_long [2468 2437 2531]
# For lat_long [31.05390545 31.41066073] the nearest lat_longs are:
# [[31.053905   31.410661  ]
#  [31.05260319 31.40793324]
#  [31.05411721 31.40267331]]
# With distances of:
# [5.62608584e-05 2.97445760e-01 7.61234917e-01]
# -------------------------------------
# Indexes of nearest lat_long [2587 2407 2491]
# For lat_long [31.1216098 31.6458735] the nearest lat_longs are:
# [[31.120718   31.646416  ]
#  [31.120718   31.646416  ]
#  [31.11867263 31.6463434 ]]
# With distances of:
# [0.11180452 0.11180452 0.32964719]
# -------------------------------------
# Indexes of nearest lat_long [306 255 214]
# For lat_long [30.82724979 31.22388209] the nearest lat_longs are:
# [[30.84995542 31.23733932]
#  [30.84995542 31.23733932]
#  [30.80125091 31.21020188]]
# With distances of:
# [2.83286147 2.83286167 3.17243005]
# -------------------------------------
# Indexes of nearest lat_long [2551 2637 2429]
# For lat_long [31.0711551 31.4175356] the nearest lat_longs are:
# [[31.06009469 31.40712784]
#  [31.0733     31.397773  ]
#  [31.0733     31.397773  ]]
# With distances of:
# [1.57963622 1.8972483  1.8972483 ]
# -------------------------------------
# Indexes of nearest lat_long [2445 2594 2404]
# For lat_long [30.8795061 31.4545693] the nearest lat_longs are:
# [[30.884141   31.459955  ]
#  [30.884141   31.459955  ]
#  [30.8866141  31.45778749]]
# With distances of:
# [0.72785244 0.72785244 0.84794254]
# -------------------------------------
# Indexes of nearest lat_long [2461 2528 2572]
# For lat_long [30.86684431 31.28240765] the nearest lat_longs are:
# [[30.866844   31.282408  ]
#  [30.86487204 31.26493098]
#  [30.84552858 31.26828212]]
# With distances of:
# [4.80017293e-05 1.68244108e+00 2.72689370e+00]
# -------------------------------------
# Indexes of nearest lat_long [2476 2610 2494]
# For lat_long [31.05021889 31.38009747] the nearest lat_longs are:
# [[31.050115 31.380445]
#  [31.050115 31.380445]
#  [31.0496   31.376869]]
# With distances of:
# [0.03506415 0.03506415 0.31515807]
# -------------------------------------
# Indexes of nearest lat_long [2498 2607 2408]
# For lat_long [31.1297027 31.4219936] the nearest lat_longs are:
# [[31.12152859 31.44418088]
#  [31.119647   31.447351  ]
#  [31.119647   31.447351  ]]
# With distances of:
# [2.29922064 2.66012508 2.66012508]
# -------------------------------------
# Indexes of nearest lat_long [2496 2487 2578]
# For lat_long [30.72166318 31.25417092] the nearest lat_longs are:
# [[30.72027286 31.25607253]
#  [30.720512   31.260394  ]
#  [30.720512   31.260394  ]]
# With distances of:
# [0.23862627 0.60848263 0.60848263]
# -------------------------------------
# Indexes of nearest lat_long [2628 2465 2605]
# For lat_long [31.03155235 31.39327318] the nearest lat_longs are:
# [[31.033786 31.395132]
#  [31.033786 31.395132]
#  [31.033861 31.395167]]
# With distances of:
# [0.30504966 0.30504966 0.31378306]
# -------------------------------------
# Indexes of nearest lat_long [2414 2602 2483]
# For lat_long [30.79208093 31.35398819] the nearest lat_longs are:
# [[30.767432 31.346599]
#  [30.767432 31.346599]
#  [30.809467 31.32078 ]]
# With distances of:
# [2.83027973 2.83027973 3.71449245]
# -------------------------------------
# Indexes of nearest lat_long [2487 2578 2492]
# For lat_long [30.71339125 31.26236442] the nearest lat_longs are:
# [[30.720512   31.260394  ]
#  [30.720512   31.260394  ]
#  [30.71171694 31.25405897]]
# With distances of:
# [0.81388779 0.81388779 0.8155261 ]
# -------------------------------------
# Indexes of nearest lat_long [2424 2449 2623]
# For lat_long [31.2112689  31.35981899] the nearest lat_longs are:
# [[31.21597938 31.35695497]
#  [31.217524   31.362288  ]
#  [31.217524   31.362288  ]]
# With distances of:
# [0.59036371 0.73409752 0.73409752]
# -------------------------------------
# Indexes of nearest lat_long [2531 2551 2405]
# For lat_long [31.05847001 31.4004809 ] the nearest lat_longs are:
# [[31.05411721 31.40267331]
#  [31.06009469 31.40712784]
#  [31.05509358 31.39160521]]
# With distances of:
# [0.52714279 0.65841255 0.92507424]
# -------------------------------------
# Indexes of nearest lat_long [2403 2447 2611]
# For lat_long [31.17330236 31.8810943 ] the nearest lat_longs are:
# [[31.17715441 31.86503844]
#  [31.16287    31.930412  ]
#  [31.16287    31.930412  ]]
# With distances of:
# [1.58642479 4.83355872 4.83355872]
# -------------------------------------
# Indexes of nearest lat_long [2557 2584 2417]
# For lat_long [31.14496486 31.71208188] the nearest lat_longs are:
# [[31.14424252 31.71973764]
#  [31.159674   31.734595  ]
#  [31.159674   31.734595  ]]
# With distances of:
# [0.73299593 2.69532768 2.69532768]
# -------------------------------------
# Indexes of nearest lat_long [2488 2638 2544]
# For lat_long [31.04127957 31.39525093] the nearest lat_longs are:
# [[31.042415   31.39422   ]
#  [31.042415   31.39422   ]
#  [31.04181016 31.39335749]]
# With distances of:
# [0.15995865 0.15995865 0.18979322]
# -------------------------------------
# Indexes of nearest lat_long [2472 2585 2509]
# For lat_long [31.14173293 31.63405195] the nearest lat_longs are:
# [[31.126376  31.651975 ]
#  [31.126376  31.651975 ]
#  [31.1216098 31.6458735]]
# With distances of:
# [2.41370926 2.41370926 2.50456562]
# -------------------------------------
# Indexes of nearest lat_long [2570 2421 2556]
# For lat_long [30.69120219 31.30860952] the nearest lat_longs are:
# [[30.692273   31.308583  ]
#  [30.692273   31.308583  ]
#  [30.69006168 31.33017883]]
# With distances of:
# [0.11909564 0.11909564 2.06636331]
# -------------------------------------
# Indexes of nearest lat_long [2503 2535  634]
# For lat_long [30.85079229 31.59031027] the nearest lat_longs are:
# [[30.89248985 31.56020697]
#  [30.85542672 31.53271891]
#  [30.798202   31.628144  ]]
# With distances of:
# [5.45456257 5.52172251 6.87369737]
# -------------------------------------
# Indexes of nearest lat_long [2513 2461 2572]
# For lat_long [30.86487204 31.26493098] the nearest lat_longs are:
# [[30.86684431 31.28240765]
#  [30.866844   31.282408  ]
#  [30.84552858 31.26828212]]
# With distances of:
# [1.68244108 1.68246971 2.1745522 ]
# -------------------------------------
# Indexes of nearest lat_long [2535 2594 2445]
# For lat_long [30.87021444 31.50347959] the nearest lat_longs are:
# [[30.85542672 31.53271891]
#  [30.884141   31.459955  ]
#  [30.884141   31.459955  ]]
# With distances of:
# [3.23925743 4.43304844 4.43304844]
# -------------------------------------
# Indexes of nearest lat_long [2542 2621 2422]
# For lat_long [31.07602081 31.49028013] the nearest lat_longs are:
# [[31.07172203 31.4940507 ]
#  [31.10732    31.507895  ]
#  [31.10732    31.507895  ]]
# With distances of:
# [0.59786481 3.863407   3.863407  ]
# -------------------------------------
# Indexes of nearest lat_long [2521 2437 2508]
# For lat_long [31.05411721 31.40267331] the nearest lat_longs are:
# [[31.05847001 31.4004809 ]
#  [31.05260319 31.40793324]
#  [31.05390545 31.41066073]]
# With distances of:
# [0.52714279 0.52858376 0.76123492]
# -------------------------------------
# Indexes of nearest lat_long [2579 2458 2576]
# For lat_long [30.90368612 31.39030235] the nearest lat_longs are:
# [[30.931001 31.357517]
#  [30.931001 31.357517]
#  [30.898103 31.342564]]
# With distances of:
# [4.35966779 4.35966779 4.59690461]
# -------------------------------------
# Indexes of nearest lat_long [2491 2407 2587]
# For lat_long [31.11825165 31.64137221] the nearest lat_longs are:
# [[31.11867263 31.6463434 ]
#  [31.120718   31.646416  ]
#  [31.120718   31.646416  ]]
# With distances of:
# [0.47553699 0.55293663 0.55293663]
# -------------------------------------
# Indexes of nearest lat_long [2537  698  636]
# For lat_long [30.82812711 31.4041259 ] the nearest lat_longs are:
# [[30.82226663 31.4356399 ]
#  [30.78929    31.393775  ]
#  [30.78929    31.393775  ]]
# With distances of:
# [3.07892688 4.43018897 4.43018897]
# -------------------------------------
# Indexes of nearest lat_long [2529 2503 2527]
# For lat_long [30.85542672 31.53271891] the nearest lat_longs are:
# [[30.87021444 31.50347959]
#  [30.89248985 31.56020697]
#  [30.85079229 31.59031027]]
# With distances of:
# [3.23925743 4.88537287 5.52172251]
# -------------------------------------
# Indexes of nearest lat_long [2475 2591 2451]
# For lat_long [30.95687282 31.53079379] the nearest lat_longs are:
# [[30.94527  31.530665]
#  [30.94527  31.530665]
#  [30.94503  31.533459]]
# With distances of:
# [1.29023317 1.29023317 1.34116402]
# -------------------------------------
# Indexes of nearest lat_long [2534  698  636]
# For lat_long [30.82226663 31.4356399 ] the nearest lat_longs are:
# [[30.82812711 31.4041259 ]
#  [30.78929    31.393775  ]
#  [30.78929    31.393775  ]]
# With distances of:
# [3.07892688 5.42517708 5.42517708]
# -------------------------------------
# Indexes of nearest lat_long [2439 2615 2400]
# For lat_long [30.99812441 31.62455783] the nearest lat_longs are:
# [[31.0159928  31.65430166]
#  [31.021598   31.64903   ]
#  [31.021598   31.64903   ]]
# With distances of:
# [3.46171853 3.50033113 3.50033113]
# -------------------------------------
# Indexes of nearest lat_long [2402 2455 2540]
# For lat_long [31.167544 31.801126] the nearest lat_longs are:
# [[31.167544 31.801126]
#  [31.167388 31.803124]
#  [31.167388 31.803124]]
# With distances of:
# [0.         0.19088921 0.19088921]
# -------------------------------------
# Indexes of nearest lat_long [2540 2402 2539]
# For lat_long [31.167388 31.803124] the nearest lat_longs are:
# [[31.167388 31.803124]
#  [31.167544 31.801126]
#  [31.167544 31.801126]]
# With distances of:
# [0.         0.19088921 0.19088921]
# -------------------------------------
# Indexes of nearest lat_long [2552 2626 2489]
# For lat_long [31.15759968 31.48638114] the nearest lat_longs are:
# [[31.16634612 31.45101234]
#  [31.188486   31.496254  ]
#  [31.188486   31.496254  ]]
# With distances of:
# [3.50306779 3.56053306 3.56053306]
# -------------------------------------
# Indexes of nearest lat_long [2530 2422 2621]
# For lat_long [31.07172203 31.4940507 ] the nearest lat_longs are:
# [[31.07602081 31.49028013]
#  [31.10732    31.507895  ]
#  [31.10732    31.507895  ]]
# With distances of:
# [0.59786481 4.17206817 4.17206817]
# -------------------------------------
# Indexes of nearest lat_long [2497 2581 2442]
# For lat_long [31.03663711 31.33568775] the nearest lat_longs are:
# [[31.03828145 31.35486177]
#  [31.043345   31.35496   ]
#  [31.043345   31.35496   ]]
# With distances of:
# [1.83593584 1.98183579 1.98183579]
# -------------------------------------

# %%
nearest_df1 = df.iloc[index1]
nearest_df1

# %%
new_df = pd.concat([df.reset_index(drop=True),nearest_df1.reset_index(drop=True)], axis=1)

# %%
dummy = [round(x, 3) for x in near_dis1]

# %%
new_df['distance1'] = dummy
new_df['distance1_in_meters'] = new_df['distance1'] * 1000
new_df

# %%
new_df.to_excel('nearest_atm2.xlsx')

# %%
sns.boxplot(new_df['distance1'])

# %%
new_df[new_df['distance1']==0]['ID'].count()

# %%
nearest_df2 = df.iloc[index2]
nearest_df2

# %%
new_df = pd.concat([new_df.reset_index(drop=True),nearest_df2.reset_index(drop=True)], axis=1)

# %%
dummy = [round(x, 3) for x in near_dis2]

# %%
new_df['distance2'] = dummy
new_df['distance2_in_meters'] = new_df['distance2'] * 1000
new_df

# %%
# model to measure whether the number of the atms satisfies some sort of equation(model) based on some features like: population number, where are the atms and any other useful features

# %%
new_df[new_df['distance2']==0]['ID'].count()

# %%
sns.boxplot(new_df['distance2'])

# %%
new_df.to_excel('nearest_atm3.xlsx')

# %%
import pandas as pd
import openpyxl
import numpy as np

pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)
pd.set_option('display.width', 10000)

# %%
df = pd.read_excel('atm_bank_misr (copy).xlsx')
df
# Out:
#         ID       governerate                                             region                                            Address        Lat       Long
# 0        1         Al Fayyum                                   Markaz Al-Fayyum                      Alfayoum Beghous Alhoriea St.  29.304412  30.853546
# 1        2         Al Fayyum                                   Markaz Al-Fayyum                                  Fayoum University  29.319696  30.835641
# 2        3         Al Fayyum                                   Markaz Al-Fayyum                                Fayoum AlHoriea St.  29.308199  30.842229
# 3        4         Al Fayyum                                    Markaz Sinnuris                                   Sanoras - Fayoum  29.408575  30.865073
# 4        5         Al Fayyum                                        Markaz Itsa      194 Abo Bakr AlSiddiq St.- Atsa City - Fayoum  29.236966  30.790194
# ...

# %%
df.groupby(['region']).size()
# Out:
# region
# AlObour city                                                   24
# City Dishna                                                    11
# City New Burj al-'Arab City                                    12
# City New Minya City                                             3
# Kism 'Abdin                                                    30
# Kism 'Ain Schams                                               25
# Kism 'Ataqah                                                    9
# Kism 10 Ramadan 1                                               4
# Kism 10 of ramadan                                             12
# Kism 15 Mayu                                                    4
# Kism Abu Radis                                                  1
# Kism Abu Zenima                                                 3
# Kism Ad-Dab'ah                                                  3
# Kism Ad-Darb al-Ahmar                                           3
# ...

# %%
new_df = df[['governerate','region']]
new_df
# Out:
#            governerate                                             region
# 0            Al Fayyum                                   Markaz Al-Fayyum
# 1            Al Fayyum                                   Markaz Al-Fayyum
# 2            Al Fayyum                                   Markaz Al-Fayyum
# 3            Al Fayyum                                    Markaz Sinnuris
# 4            Al Fayyum                                        Markaz Itsa
# 5            Al Fayyum                                   Markaz Al-Fayyum
# 6            Al Fayyum                                   Markaz Al-Fayyum
# 7            Al Fayyum                                   Markaz Al-Fayyum
# 8            Al Fayyum                                   Markaz Al-Fayyum
# 9            Al Fayyum                                   Markaz Al-Fayyum
# 10           Al Fayyum                                   Markaz Al-Fayyum
# 11           Al Fayyum                                    Markaz Ibshaway
# ...

# %%
k = new_df.groupby(['region']).size()


k.to_excel('aks.xlsx')

# %%
new_df = pd.read_excel('aks.xlsx')

# %%
new_df
# Out:
#                                                 region  Atm_count
# 0                                         AlObour city         24
# 1                                          City Dishna         11
# 2                          City New Burj al-'Arab City         12
# 3                                  City New Minya City          3
# 4                                          Kism 'Abdin         30
# 5                                     Kism 'Ain Schams         25
# 6                                         Kism 'Ataqah          9
# 7                                    Kism 10 Ramadan 1          4
# 8                                   Kism 10 of ramadan         12
# 9                                         Kism 15 Mayu          4
# 10                                      Kism Abu Radis          1
# 11                                     Kism Abu Zenima          3
# 12                                      Kism Ad-Dab'ah          3
# ...

# %%
df.groupby(['region','governerate']).size().to_excel('Atms_In_Regions.xlsx')

# %%
gov_list = []
for i in range(new_df['region'].size):
    for
    if new_df.iloc[i][0] == df['region'].iloc[i]:
        print()
        gov_list.append(df['governerate'].iloc[i])
# Out:
# 2

# %%
gov_list
# Out:
# ['Al Gharbiyah']
